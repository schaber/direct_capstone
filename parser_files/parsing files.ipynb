# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# csv_file = open('parsedhtml_data.csv', 'w')
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow(['name', 'CAS number', 'Molecular Weight'])

with open('97.html') as html_file:
    soup = BeautifulSoup (html_file, 'lxml')

chem = soup.find('table')
chem_name = chem.tbody.tr.b.text # name of the chemical 
chem_info = chem.tbody.tr.td # first level of information 


list_temp=[]

for div in chem_info.find_all('div'): #2nd level
    temp =  div.dl.dd
    for table in temp.find_all('table'): #3rd level 
        temp_1 = table.tbody.tr
#         list_temp = []
        for td in temp_1.find_all('td'): #4rd level -- actrual contents
            list_temp.append(td.text)
            
        # putting actual contents in to df

# print(list_temp)

# print(len(list_temp))

temp_properties ={}

for t_in in range(0, len(list_temp), 2):
        temp_properties[list_temp[t_in]] = list_temp[t_in + 1]
        

       
        
  
print(temp_properties)
        

#         for k,v in temp_properties.items():
#             CSV = "\n".join([k+','+','.join(v)])
#             with open("filename2.csv", "w") as file:
#                 file.write(CSV)
#         print (temp_properties)
        
#         CSV ="\n".join([k+','+','.join(v) for k,v in temp_properties.items()]) 
#         with open("filename.csv", "w") as file:
#             file.write(CSV)
# Out:
# {'Synonyms:': 'DHODA; Di-C7-9-alkyl adipate; Hexanedioic acid, di-C7-9-branched and linear alkyl esters', 'Molecular Weight:': '375', 'CAS Registry No.:': '68515-75-3', 'Chemical Category:': 'Adipates', 'EC No.:': '271-105-9', 'Manufacturer:': 'Solutia Inc.', 'Outstanding Properties:': 'Enhanced low temperature performance', 'Used for Polymeric Materials:': 'PVC, PU, cellulosics, rubber', 'Used for Products:': 'Film & sheeting, coatings', 'Specific Gravity:': '0.92 (25°C)', 'Aggregate State at 25°C:': 'Liquid', 'Surface Tension, mN/m:': '30.3 (25°C)', 'Boiling Point, °C:': '224', 'Dynamic Viscosity, cP:': '12.8 (25°C)', 'Melting Point, °C:': '-13', 'Vapor Pressure, kPa:': '0.44 (200°C)', 'Odor:': 'Odorless', 'Color:': 'Colorless', 'OSHA Hazard Class:': 'Not considered a hazardous substance', 'Autoignition Temperature, °C:': '232', 'Eye Irritation (human):': 'None - rabbit', 'Flash Point Method:': 'COC', 'Flash Point Temperature, °C:': '204', 'HMIS Fire:': '0', 'HMIS Health:': '1', 'HMIS Personal protection:': 'Safety glasses, gloves, lab. coat', 'NFPA Flammability:': '0', 'NFPA Health:': '1', 'NFPA Reactivity:': '0', 'Skin Irritation:': 'None', 'HMIS Reactivity:': '0', 'Biodegradation Probability:': 'SCAS(OECD 302A) degradation 67% 24h', 'Octanol-Water Partition Coeff., log Kow:': '7.55', 'Fathead Minnow, 96-h LC50, mg/L:': '>1,000', 'Rainbow Trout, 96-h LC50, mg/L:': '>1,000', 'Rabbit Dermal, LD50, mg/kg:': '>7,940', 'Rat Oral, LD50, mg/kg:': '>14,000'}

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# csv_file = open('parsedhtml_data.csv', 'w')
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow(['name', 'CAS number', 'Molecular Weight'])

with open('Abalyn.html') as html_file:
    soup = BeautifulSoup (html_file, 'lxml')

chem = soup.find('table')
chem_name = chem.tbody.tr.b.text # name of the chemical 
chem_info = chem.tbody.tr.td # first level of information 


list_temp=[]

for div in chem_info.find_all('div'): #2nd level
    temp =  div.dl.dd
    for table in temp.find_all('table'): #3rd level 
        temp_1 = table.tbody.tr
#         list_temp = []
        for td in temp_1.find_all('td'): #4rd level -- actrual contents
            list_temp.append(td.text)
            
        # putting actual contents in to df

# print(list_temp)

# print(len(list_temp))

temp_properties2 ={}

for t_in in range(0, len(list_temp), 2):
        temp_properties2[list_temp[t_in]] = list_temp[t_in + 1]
        

       
        
  
print(temp_properties2)
        

#         for k,v in temp_properties.items():
#             CSV = "\n".join([k+','+','.join(v)])
#             with open("filename2.csv", "w") as file:
#                 file.write(CSV)
#         print (temp_properties)
        
#         CSV ="\n".join([k+','+','.join(v) for k,v in temp_properties.items()]) 
#         with open("filename.csv", "w") as file:
#             file.write(CSV)
# Out:
# {'Synonyms:': 'Methyl ester of rosin; Methyl rosinate', 'CAS Registry No.:': '68186-14-1', 'Chemical Category:': 'Abietates', 'EC No.:': '269-035-9', 'Manufacturer:': 'Eastman Chemical (UK) Ltd.', 'Used for Products:': 'Lacquers, adhesives, sealants', 'Specific Gravity:': '1.03 (25°C)', 'Aggregate State at 25°C:': 'Liquid, viscous', 'Boiling Point, °C:': '352', 'Density, kg/m3:': '1,030 (25°C)', 'Dynamic Viscosity, cP:': '4,000 (25°C)', 'Acid Number, mg KOH/g:': '5', 'Odor:': 'Piney', 'Saponification Value, mg KOH/g:': '159', 'Color:': 'Amber', 'Color, Gardner scale:': '5', 'Refractive Index:': '1.531 (n20D)', 'OSHA Hazard Class:': 'Not considered a hazardous substance', 'UN Risk Phrases:': '43', 'UN Safety Phrases:': '23,24', 'Eye Irritation (human):': 'Causes irritation', 'Flash Point Temperature, °C:': '180', 'HMIS Fire:': '1', 'HMIS Health:': '1', 'HMIS Personal protection:': 'Chemical goggles, gloves, minimize skin contact', 'NFPA Flammability:': '1', 'NFPA Health:': '2', 'NFPA Reactivity:': '0', 'Skin Irritation:': 'May cause irritation', 'HMIS Reactivity:': '0'}

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# csv_file = open('parsedhtml_data.csv', 'w')
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow(['name', 'CAS number', 'Molecular Weight'])

with open('Acetine.html') as html_file:
    soup = BeautifulSoup (html_file, 'lxml')

chem = soup.find('table')
chem_name = chem.tbody.tr.b.text # name of the chemical 
chem_info = chem.tbody.tr.td # first level of information 


list_temp=[]

for div in chem_info.find_all('div'): #2nd level
    temp =  div.dl.dd
    for table in temp.find_all('table'): #3rd level 
        temp_1 = table.tbody.tr
#         list_temp = []
        for td in temp_1.find_all('td'): #4rd level -- actrual contents
            list_temp.append(td.text)
            
        # putting actual contents in to df

# print(list_temp)

# print(len(list_temp))

temp_properties3 ={}

for t_in in range(0, len(list_temp), 2):
        temp_properties3[list_temp[t_in]] = list_temp[t_in + 1]
        

       
        
  
print(temp_properties3)
        

#         for k,v in temp_properties.items():
#             CSV = "\n".join([k+','+','.join(v)])
#             with open("filename2.csv", "w") as file:
#                 file.write(CSV)
#         print (temp_properties)
        
#         CSV ="\n".join([k+','+','.join(v) for k,v in temp_properties.items()]) 
#         with open("filename.csv", "w") as file:
#             file.write(CSV)
# Out:
# {'Manufacturer:': 'Bayer', 'Used for Polymeric Materials:': 'PVC', 'Misc. Info on Composition:': 'Mixture of glycerine acetates', 'Aggregate State at 25°C:': 'Liquid', 'Density, kg/m3:': '974 (20°C); 970 (25°C); 960 (40°C); 954 (50°C); 945 (60°C)', 'Dynamic Viscosity, cP:': '40 (20°C); 30 (25°C); 25 (30°C); 17 (40°C)', 'Pour Point, °C:': '-12', 'Acid Number, mg KOH/g:': '0.8', 'Color:': 'Yellowish', 'Color, Platinum-Cobalt Scale:': '>250', 'Refractive Index:': '1.4478 (n20D)', 'Food Law Approvals:': 'Approved for food contact', 'Flash Point Method:': 'OC', 'Flash Point Temperature, °C:': '218'}

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# csv_file = open('parsedhtml_data.csv', 'w')
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow(['name', 'CAS number', 'Molecular Weight'])

with open('Acetulan.html') as html_file:
    soup = BeautifulSoup (html_file, 'lxml')

chem = soup.find('table')
chem_name = chem.tbody.tr.b.text # name of the chemical 
chem_info = chem.tbody.tr.td # first level of information 


list_temp=[]

for div in chem_info.find_all('div'): #2nd level
    temp =  div.dl.dd
    for table in temp.find_all('table'): #3rd level 
        temp_1 = table.tbody.tr
#         list_temp = []
        for td in temp_1.find_all('td'): #4rd level -- actrual contents
            list_temp.append(td.text)
            
        # putting actual contents in to df

# print(list_temp)

# print(len(list_temp))

temp_properties4 ={}

for t_in in range(0, len(list_temp), 2):
        temp_properties4[list_temp[t_in]] = list_temp[t_in + 1]
        

       
        
  
print(temp_properties4)
        

#         for k,v in temp_properties.items():
#             CSV = "\n".join([k+','+','.join(v)])
#             with open("filename2.csv", "w") as file:
#                 file.write(CSV)
#         print (temp_properties)
        
#         CSV ="\n".join([k+','+','.join(v) for k,v in temp_properties.items()]) 
#         with open("filename.csv", "w") as file:
#             file.write(CSV)
# Out:
# {'Synonyms:': 'Cetyl acetate; Palmityl acetate; hexadecyl acetate', 'Molecular Formula:': 'C18H36O2', 'Molecular Weight:': '284.48', 'CAS Registry No.:': '629-70-9', 'Chemical Category:': 'Others', 'RTECS No.:': 'MM0225200', 'Manufacturer:': 'Amerchol Corporation', 'Used for Products:': 'Cosmetics', 'Specific Gravity:': '0.87 (25°C)', 'Aggregate State at 25°C:': 'Liquid, viscous', 'Melting Point, °C:': '18.5', 'Iodine Value, g/100 g:': '>6', 'Saponification Value, mg KOH/g:': '190.0 (approx)', 'Color, Platinum-Cobalt Scale:': '<4', 'OSHA Hazard Class:': 'Not considered a hazardous substance', 'UN Risk Phrases:': '38', 'UN Safety Phrases:': '24', 'HMIS Fire:': '0', 'HMIS Health:': '0', 'NFPA Flammability:': '1', 'NFPA Health:': '2', 'NFPA Reactivity:': '1', 'HMIS Reactivity:': '0', 'Octanol-Water Partition Coeff., log Kow:': '7.74', 'Theoretical Oxygen Demand, ThOD, g/g:': '2.92', 'Rabbit Dermal, LD50, mg/kg:': '>5,000', 'Rat Oral, LD50, mg/kg:': '>5,000'}

# %%
data = pd.DataFrame(dict(sorted(temp_properties.items(), key = lambda x:x[0])), index = [0])
# data.append(temp_properties2,ignore_index=True)
# data.append(temp_properties3,ignore_index=True)
# data.append(temp_properties4,ignore_index=True)

# %%
data
# Out:
#   Aggregate State at 25°C: Autoignition Temperature, °C:  \
# 0                   Liquid                           232
#
#            Biodegradation Probability: Boiling Point, °C: CAS Registry No.:  \
# 0  SCAS(OECD 302A) degradation 67% 24h                224        68515-75-3
#
#   Chemical Category:     Color: Dynamic Viscosity, cP:    EC No.:  \
# 0           Adipates  Colorless            12.8 (25°C)  271-105-9
#
#   Eye Irritation (human):  ... Rabbit Dermal, LD50, mg/kg:  \
# 0           None - rabbit  ...                      >7,940
#
#   Rainbow Trout, 96-h LC50, mg/L: Rat Oral, LD50, mg/kg: Skin Irritation:  \
# 0                          >1,000                >14,000             None
#
#   Specific Gravity: Surface Tension, mN/m:  \
# 0       0.92 (25°C)            30.3 (25°C)
#
#                                            Synonyms:  \
# 0  DHODA; Di-C7-9-alkyl adipate; Hexanedioic acid...
#
#   Used for Polymeric Materials:         Used for Products:  \
# 0  PVC, PU, cellulosics, rubber  Film & sheeting, coatings
#
#   Vapor Pressure, kPa:
# 0         0.44 (200°C)
#
# [1 rows x 37 columns]

# %%
data2 = data.append(temp_properties2,ignore_index=True)

# %%
data2
# Out:
#   Aggregate State at 25°C: Autoignition Temperature, °C:  \
# 0                   Liquid                           232
# 1          Liquid, viscous                           NaN
#
#            Biodegradation Probability: Boiling Point, °C: CAS Registry No.:  \
# 0  SCAS(OECD 302A) degradation 67% 24h                224        68515-75-3
# 1                                  NaN                352        68186-14-1
#
#   Chemical Category:     Color: Dynamic Viscosity, cP:    EC No.:  \
# 0           Adipates  Colorless            12.8 (25°C)  271-105-9
# 1          Abietates      Amber           4,000 (25°C)  269-035-9
#
#   Eye Irritation (human):  ... Used for Polymeric Materials:  \
# 0           None - rabbit  ...  PVC, PU, cellulosics, rubber
# 1       Causes irritation  ...                           NaN
#
#               Used for Products: Vapor Pressure, kPa: Acid Number, mg KOH/g:  \
# 0      Film & sheeting, coatings         0.44 (200°C)                    NaN
# 1  Lacquers, adhesives, sealants                  NaN                      5
#
#   Color, Gardner scale: Density, kg/m3: Refractive Index:  \
# 0                   NaN             NaN               NaN
# 1                     5    1,030 (25°C)      1.531 (n20D)
#
#   Saponification Value, mg KOH/g: UN Risk Phrases: UN Safety Phrases:
# 0                             NaN              NaN                NaN
# 1                             159               43              23,24
#
# [2 rows x 44 columns]

# %%
data3 = data2.append(temp_properties3,ignore_index=True)

# %%
data3
# Out:
#   Aggregate State at 25°C: Autoignition Temperature, °C:  \
# 0                   Liquid                           232
# 1          Liquid, viscous                           NaN
# 2                   Liquid                           NaN
#
#            Biodegradation Probability: Boiling Point, °C: CAS Registry No.:  \
# 0  SCAS(OECD 302A) degradation 67% 24h                224        68515-75-3
# 1                                  NaN                352        68186-14-1
# 2                                  NaN                NaN               NaN
#
#   Chemical Category:     Color:                      Dynamic Viscosity, cP:  \
# 0           Adipates  Colorless                                 12.8 (25°C)
# 1          Abietates      Amber                                4,000 (25°C)
# 2                NaN  Yellowish  40 (20°C); 30 (25°C); 25 (30°C); 17 (40°C)
#
#      EC No.: Eye Irritation (human):  ... Color, Gardner scale:  \
# 0  271-105-9           None - rabbit  ...                   NaN
# 1  269-035-9       Causes irritation  ...                     5
# 2        NaN                     NaN  ...                   NaN
#
#                                      Density, kg/m3: Refractive Index:  \
# 0                                                NaN               NaN
# 1                                       1,030 (25°C)      1.531 (n20D)
# 2  974 (20°C); 970 (25°C); 960 (40°C); 954 (50°C)...     1.4478 (n20D)
#
#   Saponification Value, mg KOH/g: UN Risk Phrases: UN Safety Phrases:  \
# 0                             NaN              NaN                NaN
# 1                             159               43              23,24
# 2                             NaN              NaN                NaN
#
#   Color, Platinum-Cobalt Scale:        Food Law Approvals:  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                          >250  Approved for food contact
#
#       Misc. Info on Composition: Pour Point, °C:
# 0                            NaN             NaN
# 1                            NaN             NaN
# 2  Mixture of glycerine acetates             -12
#
# [3 rows x 48 columns]

# %%
data4 = data3.append(temp_properties4,ignore_index=True)

# %%
data4
# Out:
#   Aggregate State at 25°C: Autoignition Temperature, °C:  \
# 0                   Liquid                           232
# 1          Liquid, viscous                           NaN
# 2                   Liquid                           NaN
# 3          Liquid, viscous                           NaN
#
#            Biodegradation Probability: Boiling Point, °C: CAS Registry No.:  \
# 0  SCAS(OECD 302A) degradation 67% 24h                224        68515-75-3
# 1                                  NaN                352        68186-14-1
# 2                                  NaN                NaN               NaN
# 3                                  NaN                NaN          629-70-9
#
#   Chemical Category:     Color:                      Dynamic Viscosity, cP:  \
# 0           Adipates  Colorless                                 12.8 (25°C)
# 1          Abietates      Amber                                4,000 (25°C)
# 2                NaN  Yellowish  40 (20°C); 30 (25°C); 25 (30°C); 17 (40°C)
# 3             Others        NaN                                         NaN
#
#      EC No.: Eye Irritation (human):  ... UN Risk Phrases: UN Safety Phrases:  \
# 0  271-105-9           None - rabbit  ...              NaN                NaN
# 1  269-035-9       Causes irritation  ...               43              23,24
# 2        NaN                     NaN  ...              NaN                NaN
# 3        NaN                     NaN  ...               38                 24
#
#   Color, Platinum-Cobalt Scale:        Food Law Approvals:  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                          >250  Approved for food contact
# 3                            <4                        NaN
#
#       Misc. Info on Composition: Pour Point, °C: Iodine Value, g/100 g:  \
# 0                            NaN             NaN                    NaN
# 1                            NaN             NaN                    NaN
# 2  Mixture of glycerine acetates             -12                    NaN
# 3                            NaN             NaN                     >6
#
#   Molecular Formula: RTECS No.: Theoretical Oxygen Demand, ThOD, g/g:
# 0                NaN        NaN                                   NaN
# 1                NaN        NaN                                   NaN
# 2                NaN        NaN                                   NaN
# 3           C18H36O2  MM0225200                                  2.92
#
# [4 rows x 52 columns]

# %%
data4.to_excel('dp.xls')
